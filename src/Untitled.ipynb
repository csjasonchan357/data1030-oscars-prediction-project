# %%
df = pd.read_csv('/home/jovyan/data1030/data1030-oscars-prediction-project/data/movies.csv')
df[df['year'] == 2018]
# Out:
#       year                                   movie   movie_id certificate  \
# 772   2018                               First Man  tt1213641       PG-13
# 880   2018                          A Star Is Born  tt1517451           R
# 938   2018                        Ready Player One  tt1677720       PG-13
# 946   2018                       Bohemian Rhapsody  tt1727824       PG-13
# 968   2018                           Black Panther  tt1825683       PG-13
# 1037  2018                     Mary Queen of Scots  tt2328900           R
# 1136  2018                           Incredibles 2  tt3606756          PG
# 1146  2018                                The Wife  tt3750872           R
# 1147  2018                 Solo: A Star Wars Story  tt3778644       PG-13
# 1159  2018                  Avengers: Infinity War  tt4154756       PG-13
# 1172  2018                       Christopher Robin  tt4575576          PG
# 1173  2018                Can You Ever Forgive Me?  tt4595882           R
# 1174  2018       Spider-Man: Into the Spider-Verse  tt4633694          PG
# 1183  2018                    Mary Poppins Returns  tt5028340          PG
# 1185  2018                           The Favourite  tt5083738           R
# 1186  2018                            Isle of Dogs  tt5104604       PG-13
# 1190  2018                         Never Look Away  tt5311542           R
# 1192  2018                                  Border  tt5501104           R
# 1199  2018               Ralph Breaks the Internet  tt5848272          PG
# 1201  2018                          First Reformed  tt6053438           R
# 1202  2018                                    Roma  tt6155172           R
# 1203  2018                                    Vice  tt6266538           R
# 1205  2018            The Ballad of Buster Scruggs  tt6412452           R
# 1206  2018                                Cold War  tt6543652           R
# 1207  2018                                  Mother  tt6597824         NaN
# 1208  2018  Hale County This Morning, This Evening  tt6634646         NaN
# 1209  2018                           A Quiet Place  tt6644200       PG-13
# 1210  2018                              Marguerite  tt6803040         NaN
# 1211  2018                              Detainment  tt6813264         NaN
# 1212  2018                                   Mirai  tt6900448          PG
# 1213  2018                      At Eternity's Gate  tt6938828       PG-13
# 1214  2018                Period. End of Sentence.  tt6939026         NaN
# 1215  2018                              Green Book  tt6966692       PG-13
# 1216  2018                          Late Afternoon  tt7077824         NaN
# 1217  2018              If Beale Street Could Talk  tt7125860           R
# 1218  2018                                    Skin  tt7332306         NaN
# 1219  2018                          BlacKkKlansman  tt7349662           R
# 1220  2018                                Weekends  tt7375186         NaN
# 1221  2018                             Black Sheep  tt7440094         NaN
# 1222  2018                                LIFEBOAT  tt7446332         NaN
# 1223  2018                                   Fauve  tt7467476         NaN
# 1224  2018                         Minding the Gap  tt7476236         NaN
# 1225  2018                     Of Fathers and Sons  tt7519174         NaN
# 1226  2018                   A Night at the Garden  tt7535612         NaN
# 1227  2018                                     RBG  tt7689964          PG
# 1228  2018                               Free Solo  tt7775622       PG-13
# 1229  2018                                End Game  tt7879350       TV-PG
# 1230  2018                             Shoplifters  tt8075192           R
# 1231  2018                                     Bao  tt8075496           G
# 1232  2018                               Capernaum  tt8267604           R
# 1233  2018                        Animal Behaviour  tt8615478         NaN
# 1234  2018                          One Small Step  tt8783042         NaN
#
#       duration                       genre  rate  metascore  \
# 772        141     Biography|Drama|History   7.5       84.0
# 880        136         Drama|Music|Romance   8.0       88.0
# 938        140     Action|Adventure|Sci-Fi   7.5       64.0
# 946        134       Biography|Drama|Music   8.3       49.0
# 968        134     Action|Adventure|Sci-Fi   7.4       88.0
# 1037       124     Biography|Drama|History   6.5       60.0
# 1136       118  Animation|Action|Adventure   7.8       80.0
# 1146       100                       Drama   7.3       77.0
# 1147       135    Action|Adventure|Fantasy   7.0       62.0
# 1159       149    Action|Adventure|Fantasy   8.5       68.0
# 1172       104  Animation|Adventure|Comedy   7.4       60.0
# 1173       106      Biography|Comedy|Crime   7.6       87.0
# 1174       117  Animation|Action|Adventure   8.7       87.0
# 1183       130       Comedy|Family|Fantasy   7.2       66.0
# 1185       119      Biography|Comedy|Drama   7.9       90.0
# 1186       101  Animation|Adventure|Comedy   7.9       82.0
# 1190       188      Drama|History|Thriller   7.3       68.0
# 1192       110       Drama|Fantasy|Romance   7.3       75.0
# 1199       112  Animation|Adventure|Comedy   7.3       71.0
# 1201       113      Drama|Mystery|Thriller   7.1       85.0
# 1202       135                       Drama   8.1       96.0
# 1203       132      Biography|Comedy|Drama   7.1       61.0
# 1205       133        Comedy|Drama|Musical   7.4       79.0
# 1206        89         Drama|Music|Romance   7.8       91.0
# 1207        19                 Short|Drama   7.6        NaN
# 1208        76                 Documentary   6.8       84.0
# 1209        90        Drama|Horror|Mystery   7.6       82.0
# 1210        19                 Short|Drama   8.1        NaN
# 1211        30                 Short|Drama   8.1        NaN
# 1212        98   Animation|Adventure|Drama   7.2       81.0
# 1213       111             Biography|Drama   7.1       78.0
# 1214        26           Documentary|Short   7.8        NaN
# 1215       130      Biography|Comedy|Drama   8.3       70.0
# 1216        10             Animation|Short   7.4        NaN
# 1217       119         Crime|Drama|Romance   7.8       87.0
# 1218        20                 Short|Drama   7.2        NaN
# 1219       135       Biography|Crime|Drama   7.6       83.0
# 1220        16       Animation|Short|Drama   7.4        NaN
# 1221        26           Documentary|Short   7.5        NaN
# 1222        34           Documentary|Short   5.9        NaN
# 1223        17                 Short|Drama   7.6        NaN
# 1224        93                 Documentary   8.3       93.0
# 1225        99                 Documentary   7.6       70.0
# 1226         7           Documentary|Short   6.5        NaN
# 1227        98       Documentary|Biography   7.6       71.0
# 1228       100                 Documentary   8.6       83.0
# 1229        40           Documentary|Short   7.3        NaN
# 1230       121                 Crime|Drama   8.1       93.0
# 1231         8      Animation|Short|Family   7.5        NaN
# 1232       126                       Drama   8.1       74.0
# 1233        14      Animation|Short|Comedy   6.4        NaN
# 1234         8   Animation|Short|Adventure   7.3        NaN
#
#                                                synopsis   votes  ...  \
# 772   A look at the life of the astronaut, Neil Arms...   82345  ...
# 880   A musician helps a young singer find fame, eve...  145901  ...
# 938   When the creator of a virtual reality world ca...  269231  ...
# 946   The story of the legendary rock band Queen and...  195284  ...
# 968   T'Challa, heir to the hidden but advanced king...  447563  ...
# 1037  Mary Stuart's attempt to overthrow her cousin ...    5558  ...
# 1136  The Incredibles hero family takes on a new mis...  167035  ...
# 1146  A wife questions her life choices as she trave...    8428  ...
# 1147  During an adventure into the criminal underwor...  196202  ...
# 1159  The Avengers and their allies must be willing ...  572401  ...
# 1172  A working-class family man, Christopher Robin,...   39234  ...
# 1173  When Lee Israel falls out of step with current...    3836  ...
# 1174  Teen Miles Morales becomes Spider-Man of his r...   84106  ...
# 1183  Decades after her original visit, the magical ...   29620  ...
# 1185  In early 18th century England, a frail Queen A...   28329  ...
# 1186  Set in Japan, Isle of Dogs follows a boy's ody...   91447  ...
# 1190  German artist Kurt Barnert has escaped East Ge...    1010  ...
# 1192  A customs officer who can smell fear develops ...    3254  ...
# 1199  Six years after the events of "Wreck-It Ralph,...   39583  ...
# 1201  A minister of a small congregation in upstate ...   23248  ...
# 1202  A year in the life of a middle-class family's ...   54490  ...
# 1203  The story of Dick Cheney, an unassuming bureau...   17986  ...
# 1205  Six tales of life and violence in the Old West...   61551  ...
# 1206  A passionate love story between two people of ...   16874  ...
# 1207  While at home in her apartment with her own mo...     131  ...
# 1208  Composed of intimate and unencumbered moments ...     173  ...
# 1209  In a post-apocalyptic world, a family is force...  262896  ...
# 1210  An aging woman and her nurse develop a friends...     135  ...
# 1211  Two ten year-old boys are detained by police u...     333  ...
# 1212  A young boy encounters a magical garden which ...    1430  ...
# 1213  A look at the life of painter Vincent van Gogh...    2258  ...
# 1214  In a rural village outside Delhi, India, women...      30  ...
# 1215  A working-class Italian-American bouncer becom...   28260  ...
# 1216  An elderly woman drifts back through her memor...     286  ...
# 1217  A woman in Harlem embraces her pregnancy while...    5520  ...
# 1218  A small supermarket in a blue collar town, a b...     174  ...
# 1219  Ron Stallworth, an African American police off...   87381  ...
# 1220  'Weekends' is the story of a young boy shuffli...     193  ...
# 1221  After the high-profile killing of Damilola Tay...     125  ...
# 1222  Volunteers from a German non-profit risk the w...      40  ...
# 1223  Set in a surface mine, two boys sink into a se...     526  ...
# 1224  Three young men bond together to escape volati...    1711  ...
# 1225  Talal Derki returns to his homeland where he g...     364  ...
# 1226  Archival footage of an American Nazi rally tha...     130  ...
# 1227  The exceptional life and career of U.S. Suprem...    4781  ...
# 1228  Follow Alex Honnold as he becomes the first pe...    3802  ...
# 1229  Filmed and edited in intimate vérité style, th...     344  ...
# 1230  A family of small-time crooks take in a child ...   11471  ...
# 1231  A Chinese-Canadian woman suffering from empty ...   14730  ...
# 1232  While serving a five-year sentence for a viole...    2964  ...
# 1233  Animated anthropomorphized characters in a the...     195  ...
# 1234  TAIKO Studios presents the story of Luna, a Ch...     424  ...
#
#       New_York_Film_Critics_Circle_nominated  \
# 772                                        0
# 880                                        0
# 938                                        0
# 946                                        0
# 968                                        0
# 1037                                       0
# 1136                                       0
# 1146                                       0
# 1147                                       0
# 1159                                       0
# 1172                                       0
# 1173                                       1
# 1174                                       1
# 1183                                       0
# 1185                                       0
# 1186                                       0
# 1190                                       0
# 1192                                       0
# 1199                                       0
# 1201                                       2
# 1202                                       3
# 1203                                       0
# 1205                                       0
# 1206                                       1
# 1207                                       0
# 1208                                       0
# 1209                                       0
# 1210                                       0
# 1211                                       0
# 1212                                       0
# 1213                                       0
# 1214                                       0
# 1215                                       0
# 1216                                       0
# 1217                                       1
# 1218                                       0
# 1219                                       0
# 1220                                       0
# 1221                                       0
# 1222                                       0
# 1223                                       0
# 1224                                       1
# 1225                                       0
# 1226                                       0
# 1227                                       0
# 1228                                       0
# 1229                                       0
# 1230                                       0
# 1231                                       0
# 1232                                       0
# 1233                                       0
# 1234                                       0
#
#      New_York_Film_Critics_Circle_nominated_categories  \
# 772                                                NaN
# 880                                                NaN
# 938                                                NaN
# 946                                                NaN
# 968                                                NaN
# 1037                                               NaN
# 1136                                               NaN
# 1146                                               NaN
# 1147                                               NaN
# 1159                                               NaN
# 1172                                               NaN
# 1173                             Best Supporting Actor
# 1174                                Best Animated Film
# 1183                                               NaN
# 1185                                               NaN
# 1186                                               NaN
# 1190                                               NaN
# 1192                                               NaN
# 1199                                               NaN
# 1201                        Best Screenplay|Best Actor
# 1202      Best Film|Best Director|Best Cinematographer
# 1203                                               NaN
# 1205                                               NaN
# 1206                        Best Foreign Language Film
# 1207                                               NaN
# 1208                                               NaN
# 1209                                               NaN
# 1210                                               NaN
# 1211                                               NaN
# 1212                                               NaN
# 1213                                               NaN
# 1214                                               NaN
# 1215                                               NaN
# 1216                                               NaN
# 1217                           Best Supporting Actress
# 1218                                               NaN
# 1219                                               NaN
# 1220                                               NaN
# 1221                                               NaN
# 1222                                               NaN
# 1223                                               NaN
# 1224                             Best Non-Fiction Film
# 1225                                               NaN
# 1226                                               NaN
# 1227                                               NaN
# 1228                                               NaN
# 1229                                               NaN
# 1230                                               NaN
# 1231                                               NaN
# 1232                                               NaN
# 1233                                               NaN
# 1234                                               NaN
#
#       Los_Angeles_Film_Critics_Association_won  \
# 772                                          0
# 880                                          0
# 938                                          0
# 946                                          0
# 968                                          1
# 1037                                         0
# 1136                                         0
# 1146                                         0
# 1147                                         0
# 1159                                         0
# 1172                                         0
# 1173                                         1
# 1174                                         1
# 1183                                         0
# 1185                                         1
# 1186                                         0
# 1190                                         0
# 1192                                         0
# 1199                                         0
# 1201                                         1
# 1202                                         2
# 1203                                         0
# 1205                                         0
# 1206                                         0
# 1207                                         0
# 1208                                         0
# 1209                                         0
# 1210                                         0
# 1211                                         0
# 1212                                         0
# 1213                                         0
# 1214                                         0
# 1215                                         0
# 1216                                         0
# 1217                                         2
# 1218                                         0
# 1219                                         0
# 1220                                         0
# 1221                                         0
# 1222                                         0
# 1223                                         0
# 1224                                         1
# 1225                                         0
# 1226                                         0
# 1227                                         0
# 1228                                         0
# 1229                                         0
# 1230                                         1
# 1231                                         0
# 1232                                         0
# 1233                                         0
# 1234                                         0
#
#       Los_Angeles_Film_Critics_Association_won_categories  \
# 772                                                 NaN
# 880                                                 NaN
# 938                                                 NaN
# 946                                                 NaN
# 968                              Best Production Design
# 1037                                                NaN
# 1136                                                NaN
# 1146                                                NaN
# 1147                                                NaN
# 1159                                                NaN
# 1172                                                NaN
# 1173                                    Best Screenplay
# 1174                                     Best Animation
# 1183                                                NaN
# 1185                                       Best Actress
# 1186                                                NaN
# 1190                                                NaN
# 1192                                                NaN
# 1199                                                NaN
# 1201                                         Best Actor
# 1202                   Best Picture|Best Cinematography
# 1203                                                NaN
# 1205                                                NaN
# 1206                                                NaN
# 1207                                                NaN
# 1208                                                NaN
# 1209                                                NaN
# 1210                                                NaN
# 1211                                                NaN
# 1212                                                NaN
# 1213                                                NaN
# 1214                                                NaN
# 1215                                                NaN
# 1216                                                NaN
# 1217                 Best Supporting Actress|Best Music
# 1218                                                NaN
# 1219                                                NaN
# 1220                                                NaN
# 1221                                                NaN
# 1222                                                NaN
# 1223                                                NaN
# 1224                                       Best Editing
# 1225                                                NaN
# 1226                                                NaN
# 1227                                                NaN
# 1228                                                NaN
# 1229                                                NaN
# 1230                                  Best Foreign Film
# 1231                                                NaN
# 1232                                                NaN
# 1233                                                NaN
# 1234                                                NaN
#
#       Los_Angeles_Film_Critics_Association_nominated  \
# 772                                                1
# 880                                                0
# 938                                                0
# 946                                                0
# 968                                                1
# 1037                                               0
# 1136                                               1
# 1146                                               0
# 1147                                               0
# 1159                                               0
# 1172                                               0
# 1173                                               1
# 1174                                               1
# 1183                                               0
# 1185                                               3
# 1186                                               0
# 1190                                               0
# 1192                                               0
# 1199                                               0
# 1201                                               1
# 1202                                               4
# 1203                                               0
# 1205                                               0
# 1206                                               0
# 1207                                               0
# 1208                                               0
# 1209                                               0
# 1210                                               0
# 1211                                               0
# 1212                                               0
# 1213                                               0
# 1214                                               0
# 1215                                               0
# 1216                                               0
# 1217                                               3
# 1218                                               0
# 1219                                               0
# 1220                                               0
# 1221                                               0
# 1222                                               0
# 1223                                               0
# 1224                                               2
# 1225                                               0
# 1226                                               0
# 1227                                               0
# 1228                                               0
# 1229                                               0
# 1230                                               1
# 1231                                               0
# 1232                                               0
# 1233                                               0
# 1234                                               0
#
#       Los_Angeles_Film_Critics_Association_nominated_categories  \
# 772                                          Best Music
# 880                                                 NaN
# 938                                                 NaN
# 946                                                 NaN
# 968                              Best Production Design
# 1037                                                NaN
# 1136                                     Best Animation
# 1146                                                NaN
# 1147                                                NaN
# 1159                                                NaN
# 1172                                                NaN
# 1173                                    Best Screenplay
# 1174                                     Best Animation
# 1183                                                NaN
# 1185  Best Actress|Best Screenplay|Best Production D...
# 1186                                                NaN
# 1190                                                NaN
# 1192                                                NaN
# 1199                                                NaN
# 1201                                         Best Actor
# 1202  Best Picture|Best Cinematography|Best Director...
# 1203                                                NaN
# 1205                                                NaN
# 1206                                                NaN
# 1207                                                NaN
# 1208                                                NaN
# 1209                                                NaN
# 1210                                                NaN
# 1211                                                NaN
# 1212                                                NaN
# 1213                                                NaN
# 1214                                                NaN
# 1215                                                NaN
# 1216                                                NaN
# 1217  Best Supporting Actress|Best Music|Best Cinema...
# 1218                                                NaN
# 1219                                                NaN
# 1220                                                NaN
# 1221                                                NaN
# 1222                                                NaN
# 1223                                                NaN
# 1224     Best Editing|Best Documentary/Non-Fiction Film
# 1225                                                NaN
# 1226                                                NaN
# 1227                                                NaN
# 1228                                                NaN
# 1229                                                NaN
# 1230                                  Best Foreign Film
# 1231                                                NaN
# 1232                                                NaN
# 1233                                                NaN
# 1234                                                NaN
#
#       release_date.year release_date.month release_date.day-of-month  \
# 772              2018.0               10.0                      12.0
# 880              2018.0               10.0                       5.0
# 938              2018.0                3.0                      29.0
# 946              2018.0               11.0                       2.0
# 968              2018.0                2.0                      16.0
# 1037             2018.0               12.0                      21.0
# 1136             2018.0                6.0                      15.0
# 1146                NaN                NaN                       NaN
# 1147             2018.0                5.0                      25.0
# 1159             2018.0                4.0                      27.0
# 1172             2018.0                8.0                       3.0
# 1173             2018.0               11.0                       2.0
# 1174             2018.0               12.0                      14.0
# 1183             2018.0               12.0                      19.0
# 1185             2018.0               12.0                      21.0
# 1186             2018.0                4.0                      13.0
# 1190             2018.0               10.0                       3.0
# 1192             2018.0               10.0                      26.0
# 1199             2018.0               11.0                      21.0
# 1201             2018.0                5.0                      18.0
# 1202                NaN                NaN                       NaN
# 1203             2018.0               12.0                      25.0
# 1205             2018.0               11.0                       9.0
# 1206             2018.0               12.0                      21.0
# 1207                NaN                NaN                       NaN
# 1208                NaN                NaN                       NaN
# 1209             2018.0                4.0                       6.0
# 1210                NaN                NaN                       NaN
# 1211                NaN                NaN                       NaN
# 1212             2018.0                7.0                      20.0
# 1213                NaN                NaN                       NaN
# 1214                NaN                NaN                       NaN
# 1215             2018.0               11.0                      16.0
# 1216                NaN                NaN                       NaN
# 1217             2018.0               12.0                      25.0
# 1218                NaN                NaN                       NaN
# 1219             2018.0                8.0                      10.0
# 1220             2018.0                4.0                      19.0
# 1221                NaN                NaN                       NaN
# 1222                NaN                NaN                       NaN
# 1223                NaN                NaN                       NaN
# 1224                NaN                NaN                       NaN
# 1225                NaN                NaN                       NaN
# 1226                NaN                NaN                       NaN
# 1227                NaN                NaN                       NaN
# 1228                NaN                NaN                       NaN
# 1229                NaN                NaN                       NaN
# 1230                NaN                NaN                       NaN
# 1231             2018.0                6.0                      15.0
# 1232                NaN                NaN                       NaN
# 1233             2018.0                6.0                      11.0
# 1234             2018.0                6.0                      25.0
#
#      release_date.day-of-week
# 772                       5.0
# 880                       5.0
# 938                       4.0
# 946                       5.0
# 968                       5.0
# 1037                      5.0
# 1136                      5.0
# 1146                      NaN
# 1147                      5.0
# 1159                      5.0
# 1172                      5.0
# 1173                      5.0
# 1174                      5.0
# 1183                      3.0
# 1185                      5.0
# 1186                      5.0
# 1190                      3.0
# 1192                      5.0
# 1199                      3.0
# 1201                      5.0
# 1202                      NaN
# 1203                      2.0
# 1205                      5.0
# 1206                      5.0
# 1207                      NaN
# 1208                      NaN
# 1209                      5.0
# 1210                      NaN
# 1211                      NaN
# 1212                      5.0
# 1213                      NaN
# 1214                      NaN
# 1215                      5.0
# 1216                      NaN
# 1217                      2.0
# 1218                      NaN
# 1219                      5.0
# 1220                      4.0
# 1221                      NaN
# 1222                      NaN
# 1223                      NaN
# 1224                      NaN
# 1225                      NaN
# 1226                      NaN
# 1227                      NaN
# 1228                      NaN
# 1229                      NaN
# 1230                      NaN
# 1231                      5.0
# 1232                      NaN
# 1233                      1.0
# 1234                      1.0
#
# [52 rows x 119 columns]

# %%
import pandas 
import matplotlib 
import seaborn
import numpy 
import sklearn 
import xgboost 

print('pandas=='+str(pandas.__version__))
print('matplotlib=='+str(matplotlib.__version__))
print('seaborn=='+str(seaborn.__version__))
print('numpy=='+str(numpy.__version__))
print('sklearn=='+str(sklearn.__version__))
print('xgboost=='+str(xgboost.__version__))
# Out:
# pandas==0.25.0
# matplotlib==3.1.1
# seaborn==0.9.0
# numpy==1.17.1
# sklearn==0.21.3
# xgboost==0.90

# %%
np.sort(np.concatenate([[2],  np.logspace(1,2,2)/2 , np.logspace(1,2,2)]))
# Out:
# array([  2.,   5.,  10.,  50., 100.])

# %%
np.sort(np.concatenate([[2],  np.logspace(1,2,2)/2 , np.logspace(1,2,2)]))
# Out:
# array([  2.,   5.,  10.,  50., 100.])

# %%
np.arange(2,23,5)np.arange(2,23,5)
# Out:
# array([ 2,  7, 12, 17, 22])

# %%
import pandas as pd
from matplotlib import pyplot as plt
mv_pp = pd.read_csv('/home/jovyan/data1030/data1030-oscars-prediction-project/data/preprocessed_movies.csv')
mv = pd.read_csv('/home/jovyan/data1030/data1030-oscars-prediction-project/data/movies.csv')
mv_pp.shape
# Out:
# (1235, 1017)

# %%
# from the pymice package 
# https://github.com/RianneSchouten/pymice

import numpy as np
import pandas as pd
import math as ma
import scipy.stats as st

def checks_input_mcar_tests(data):
    """ Checks whether the input parameter of class McarTests is correct
            Parameters
            ----------
            data:
                The input of McarTests specified as 'data'
            Returns
            -------
            bool
                True if input is correct
            """

    if not isinstance(data, pd.DataFrame):
        print("Error: Data should be a Pandas DataFrame")
        return False

    if not any(data.dtypes.values == np.float):
        if not any(data.dtypes.values == np.int):
            print("Error: Dataset cannot contain other value types than floats and/or integers")
            return False

    if not data.isnull().values.any():
        print("Error: No NaN's in given data")
        return False

    return True


def mcar_test(data):
    """ Implementation of Little's MCAR test
    Parameters
    ----------
    data: Pandas DataFrame
        An incomplete dataset with samples as index and variables as columns
    Returns
    -------
    p_value: Float
        This value is the outcome of a chi-square statistical test, testing whether the null hypothesis
        'the missingness mechanism of the incomplete dataset is MCAR' can be rejected.
    """

    if not checks_input_mcar_tests(data):
        raise Exception("Input not correct")

    dataset = data.copy()
    vars = dataset.dtypes.index.values
    n_var = dataset.shape[1]

    # mean and covariance estimates
    # ideally, this is done with a maximum likelihood estimator
    gmean = dataset.mean()
    gcov = dataset.cov()

    # set up missing data patterns
    r = 1 * dataset.isnull()
    mdp = np.dot(r, list(map(lambda x: ma.pow(2, x), range(n_var))))
    sorted_mdp = sorted(np.unique(mdp))
    n_pat = len(sorted_mdp)
    correct_mdp = list(map(lambda x: sorted_mdp.index(x), mdp))
    dataset['mdp'] = pd.Series(correct_mdp, index=dataset.index)

    # calculate statistic and df
    pj = 0
    d2 = 0
    for i in range(n_pat):
        dataset_temp = dataset.loc[dataset['mdp'] == i, vars]
        select_vars = ~dataset_temp.isnull().any()
        pj += np.sum(select_vars)
        select_vars = vars[select_vars]
        means = dataset_temp[select_vars].mean() - gmean[select_vars]
        select_cov = gcov.loc[select_vars, select_vars]
        mj = len(dataset_temp)
        parta = np.dot(means.T, np.linalg.solve(select_cov, np.identity(select_cov.shape[1])))
        d2 += mj * (np.dot(parta, means))

    df = pj - n_var

    # perform test and save output
    p_value = 1 - st.chi2.cdf(d2, df)

    return p_value

# %%
df = pd.read_csv('/home/jovyan/data1030/data1030-oscars-prediction-project/data/movies.csv')

bar_cats =['New_York_Film_Critics_Circle_won_categories','Hollywood_Film_won_categories','Hollywood_Film_nominated_categories','Austin_Film_Critics_Association_won_categories','Austin_Film_Critics_Association_nominated_categories','Denver_Film_Critics_Society_won_categories','Denver_Film_Critics_Society_nominated_categories','Boston_Society_of_Film_Critics_won_categories','Boston_Society_of_Film_Critics_nominated_categories','New_York_Film_Critics_Circle_nominated_categories','Los_Angeles_Film_Critics_Association_won_categories','Los_Angeles_Film_Critics_Association_nominated_categories','Online_Film_Critics_Society_won_categories','Online_Film_Critics_Society_nominated_categories','People_Choice_won_categories','People_Choice_nominated_categories','London_Critics_Circle_Film_won_categories','London_Critics_Circle_Film_nominated_categories','American_Cinema_Editors_won_categories','American_Cinema_Editors_nominated_categories','Costume_Designers_Guild_won_categories','Costume_Designers_Guild_nominated_categories','Online_Film_Television_Association_won_categories','Online_Film_Television_Association_nominated_categories','Producers_Guild_won_categories','Producers_Guild_nominated_categories','Art_Directors_Guild_won_categories','Art_Directors_Guild_nominated_categories','Writers_Guild_won_categories','Writers_Guild_nominated_categories','Critics_Choice_won_categories','Critics_Choice_nominated_categories','Directors_Guild_won_categories','Directors_Guild_nominated_categories','Screen_Actors_Guild_won_categories','Screen_Actors_Guild_nominated_categories','BAFTA_won_categories','BAFTA_nominated_categories','Golden_Globes_won_categories','Golden_Globes_nominated_categories','Oscar_nominated_categories','genre']
bar_ohe = []
for label in bar_cats:
    df[label].fillna("nan", inplace=True)
    cat_series = df[label].apply(lambda x: (x.split('|')))
    cats = [cat  for ele in list(cat_series) for cat in ele]
    cat_set = set(cats)
    if 'nan' in cat_set:
        cat_set.remove('nan')
    total_cats = list(cat_set)
    cat_cols = [label + ": " + x for x in total_cats]

    mv_vals = np.asarray(cat_series)
    cat_ohe = np.zeros((len(cat_series),len(total_cats)))
    for i in range(len(mv_vals)):
        for j in range(len(total_cats)):
            cat_ohe[i,j] = total_cats[j] in mv_vals[i]
    ohe = pd.DataFrame(cat_ohe, columns = cat_cols)
    bar_ohe.append(ohe)
bar_ohe = pd.concat(bar_ohe,axis=1)  

ord_cols = 'Oscar_Best_Picture_won,Oscar_Best_Picture_nominated,Oscar_Best_Director_won,Oscar_Best_Director_nominated,Oscar_Best_Actor_won,Oscar_Best_Actor_nominated,Oscar_Best_Actress_won,Oscar_Best_Actress_nominated,Oscar_Best_Supporting_Actor_won,Oscar_Best_Supporting_Actor_nominated,Oscar_Best_Supporting_Actress_won,Oscar_Best_Supporting_Actress_nominated,Oscar_Best_AdaScreen_won,Oscar_Best_AdaScreen_nominated,Oscar_Best_OriScreen_won,Oscar_Best_OriScreen_nominated'
ord_cols = [x for x in ord_cols.split(',')]
for col in ord_cols:
    df[col].replace({'Yes':1,'No':0}, inplace=True)

# %%
from sklearn.preprocessing import OneHotEncoder
ohe = OneHotEncoder(sparse=False, handle_unknown='ignore')
ohe_data = pd.DataFrame(ohe.fit_transform(np.array(df['certificate'].replace({np.nan:"Missing"})).reshape(-1,1)))
ohe_data.columns = ohe.get_feature_names(['certificate'])

df = pd.concat([df, bar_ohe, ohe_data],axis=1)

# %%
drop_cols =['certificate','movie_id','synopsis','New_York_Film_Critics_Circle_won_categories','Hollywood_Film_won_categories','Hollywood_Film_nominated_categories','Austin_Film_Critics_Association_won_categories','Austin_Film_Critics_Association_nominated_categories','Denver_Film_Critics_Society_won_categories','Denver_Film_Critics_Society_nominated_categories','Boston_Society_of_Film_Critics_won_categories','Boston_Society_of_Film_Critics_nominated_categories','New_York_Film_Critics_Circle_nominated_categories','Los_Angeles_Film_Critics_Association_won_categories','Los_Angeles_Film_Critics_Association_nominated_categories','Online_Film_Critics_Society_won_categories','Online_Film_Critics_Society_nominated_categories','People_Choice_won_categories','People_Choice_nominated_categories','London_Critics_Circle_Film_won_categories','London_Critics_Circle_Film_nominated_categories','American_Cinema_Editors_won_categories','American_Cinema_Editors_nominated_categories','Costume_Designers_Guild_won_categories','Costume_Designers_Guild_nominated_categories','Online_Film_Television_Association_won_categories','Online_Film_Television_Association_nominated_categories','Producers_Guild_won_categories','Producers_Guild_nominated_categories','Art_Directors_Guild_won_categories','Art_Directors_Guild_nominated_categories','Writers_Guild_won_categories','Writers_Guild_nominated_categories','Critics_Choice_won_categories','Critics_Choice_nominated_categories','Directors_Guild_won_categories','Directors_Guild_nominated_categories','Screen_Actors_Guild_won_categories','Screen_Actors_Guild_nominated_categories','BAFTA_won_categories','BAFTA_nominated_categories','Golden_Globes_won_categories','Golden_Globes_nominated_categories','Oscar_nominated_categories','genre','year','release_date','release_date.year', 'release_date.month', 'release_date.day-of-month', 'release_date.day-of-week']
df.drop(columns = drop_cols, inplace = True)

# %%
ind = []
i = 0
for col in df.columns:
    if not (df[col].dtype == float or df[col].dtype == int):
        ind.append(i)
    i += 1
df.columns[ind]
# Out:
# Index(['movie'], dtype='object')

# %%
print("Of the features that have missing values, the fraction of missing values is:")
nulls = df.isnull().sum(axis=0)/df.shape[0]
print(nulls[nulls > 0])
print("")
print("The total fraction of missing features in the data set is:")
print(sum(df.isnull().sum(axis=1)!=0)/df.shape[0])
print("")
print("The MCAR test p-value is:")
mcar_test(df)
# Out:
# Of the features that have missing values, the fraction of missing values is:
# metascore         0.023482
# gross             0.034008
# user_reviews      0.011336
# critic_reviews    0.008097
# popularity        0.109312
# dtype: float64
#
# The total fraction of missing features in the data set is:
# 0.12874493927125505
#
# The MCAR test p-value is:
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py:1404: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_tuple(key)
# nan
